# %%
import numpy as np
import matplotlib.pyplot as plt
import mysolver as solver

# %% [markdown]
# # Forced Oscillation

# %%
def oscillator(t,y,K,M,L,F,wf):
        """
        The derivate function for an oscillator
        In this example, we set

        y[0] = x
        y[1] = v

        yderive[0] = x' = v
        yderive[1] = v' = a

        :param t: the time
        :param y: the input values
        :param K: the spring constant
        :param M: the mass of the oscillator
        :param L: the damping constant
        :param args: extra parameters, here args=(K,M,L) 

        """

        yderive    = np.zeros(shape=y.shape)
        yderive[0] = y[1]
        yderive[1] = F*np.cos(wf*t)-L/M*y[1]-K/M*y[0]

        return yderive

# %%
# TODO: solve the IVP for a forced oscillation

A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.3 # the damping
F = 0.05
wf = 0.99
N = 200 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

# %%
sol_Euler = solver.solve_ivp(oscillator, t_span, y0, 
                             method='Euler', t_eval = t_eval, args = (K,M,L,F,wf))

# %%
sol_RK2 = solver.solve_ivp(oscillator, t_span, y0, 
                           method='RK2', t_eval = t_eval, args = (K,M,L,F,wf))

# %%
sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                           method='RK4', t_eval = t_eval, args = (K,M,L,F,wf))

# %%
# TODO: visualize your results

#plt.plot(t_eval, sol_Euler[0], label='Euler')
plt.plot(t_eval, sol_RK2[0], label='RK2')
plt.plot(t_eval, sol_RK4[0], label='RK4')
plt.legend()

# %%
# Calculate analytical solution here

t = np.linspace(t_span[0], t_span[1], 20)
phi = -np.pi/2
y_analytical = -A*np.exp(-r*t)*np.sin(w*t+phi)
v_analytical = -A*(-r*np.exp(-r*t)*np.sin(w*t+phi)+w*np.exp(-r*t)*np.cos(w*t+phi))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5864\3143220310.py in <module>
#       3 t = np.linspace(t_span[0], t_span[1], 20)
#       4 phi = -np.pi/2
# ----> 5 y_analytical = -A*np.exp(-r*t)*np.sin(w*t+phi)
#       6 v_analytical = -A*(-r*np.exp(-r*t)*np.sin(w*t+phi)+w*np.exp(-r*t)*np.cos(w*t+phi))
#
# NameError: name 'r' is not defined

# %% [markdown]
# # Performance
#
# Use the `%timeit` function to compare the performance of different numerical methods

# %%
# TODO: Performance calculations

# %% [markdown]
# # Use Scipy (`scipy.integreate.solve_ivp`)
#
# see https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.solve_ivp.html

# %%
import scipy.integrate as ode

# %%
# TODO: use scipy to solve the same ODE

# %%
# TODO: compare the results. Are your own results same as the scipy's result?

# %%
# TODO: compare the performnace. Can you explain your performance results?

# %%
A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.01 # the damping
F = 0.5
dt = 0.05
wf = np.linspace(0.5, 1.5, int(1/dt)+1)
print(wf)
N = 501 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

print(t_eval[int((N-1)/5*4)])
print(t_eval[-1])

T = t_eval[-1] - t_eval[int((N-1)/5*4)]

D = []

for w in wf:
    
    sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                               method='RK4', t_eval = t_eval, args = (K,M,L,F,w))
    
    D.append(sum(abs(sol_RK4[0]))*dt/T)
    
plt.plot(wf, D)

plt.savefig('3_a');
# Out:
# [0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15
#  1.2  1.25 1.3  1.35 1.4  1.45 1.5 ]
# 40.0
# 50.0

# %%
A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.1 # the damping
F = 0.5
dt = 0.05
wf = np.linspace(0.5, 1.5, int(1/dt)+1)
print(wf)
N = 501 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

print(t_eval[int((N-1)/5*4)])
print(t_eval[-1])

T = t_eval[-1] - t_eval[int((N-1)/5*4)]

D = []

for w in wf:
    
    sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                               method='RK4', t_eval = t_eval, args = (K,M,L,F,w))
    
    D.append(sum(abs(sol_RK4[0]))*dt/T)
    
plt.plot(wf, D)

plt.savefig('3_b');
# Out:
# [0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15
#  1.2  1.25 1.3  1.35 1.4  1.45 1.5 ]
# 40.0
# 50.0

# %%
A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.3 # the damping
F = 0.5
dt = 0.05
wf = np.linspace(0.5, 1.5, int(1/dt)+1)
print(wf)
N = 501 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

print(t_eval[int((N-1)/5*4)])
print(t_eval[-1])

T = t_eval[-1] - t_eval[int((N-1)/5*4)]

D = []

for w in wf:
    
    sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                               method='RK4', t_eval = t_eval, args = (K,M,L,F,w))
    
    D.append(sum(abs(sol_RK4[0]))*dt/T)
    
plt.plot(wf, D)

plt.savefig('3_c');
# Out:
# [0.5  0.55 0.6  0.65 0.7  0.75 0.8  0.85 0.9  0.95 1.   1.05 1.1  1.15
#  1.2  1.25 1.3  1.35 1.4  1.45 1.5 ]
# 40.0
# 50.0

# %%
# TODO: solve the IVP for a forced oscillation

A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.8 # the damping
F = 0.05
wf = 0.7
N = 200 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                           method='RK4', t_eval = t_eval, args = (K,M,L,F,wf))

sol_RK4_der   = sol_RK4[0,1:] - sol_RK4[0,0:-1]

t_eval_der = t_eval[1:] - t_eval[0:-1]

plt.plot(t_eval[1:], sol_RK4_der/t_eval_der, label='RK4')
plt.savefig('4_b_current.png');

# %%
# TODO: solve the IVP for a forced oscillation

A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.8 # the damping
F = 0.05
wf = 0.7
N = 200 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                           method='RK4', t_eval = t_eval, args = (K,M,L,F,wf))

dq = sol_RK4[0,1:] - sol_RK4[0,0:-1]

dt = t_eval[1:] - t_eval[0:-1]

I = sol_RK4_der/t_eval_der

dI   = I[1:] - I[0:-1]

plt.plot(t_eval[2:], -M*dI/dt[1:], label='RK4')
plt.savefig('4_b_VL.png');

# %%
A = 1 # the initial amplitude
V = 0 # the initial velocity
K = 1 # the spring constant
M = 1 # the mass
L = 0.8 # the damping
F = 0.05
dt = 0.1
wf = np.linspace(0.3, 1.5, int(1.2/dt)+2)
print(wf)
N = 501 # the time partion number

t_span = (0, 50)
y0     = np.array([A,V])
t_eval = np.linspace(t_span[0], t_span[1], N)

print(t_eval[int((N-1)/5*4)])
print(t_eval[-1])

T = t_eval[-1] - t_eval[int((N-1)/5*4)]

D = []

for w in wf:
    
    sol_RK4 = solver.solve_ivp(oscillator, t_span, y0, 
                               method='RK4', t_eval = t_eval, args = (K,M,L,F,w))
    
    D.append(sum(abs(sol_RK4[0]))*dt/T)
    
plt.plot(wf, D)
plt.plot(wf, D)
plt.grid()

plt.savefig('4_c');
# Out:
# [0.3 0.4 0.5 0.6 0.7 0.8 0.9 1.  1.1 1.2 1.3 1.4 1.5]
# 40.0
# 50.0
